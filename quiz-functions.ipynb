# %%
def my_product(num1, num2):
  print(num1, num2)

# %%
amount = my_product(3, 2) + 1
# Out:
# 3 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-43200434567d> in <module>()
# ----> 1 amount = my_product(3, 2) + 1
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
num1 = 8
num2 = 4

def my_function():
  num1 = 12
  return num1 + num2

# %%
print(my_function())
# Out:
# 16

# %%
def myfunction(a, b, c = 5, d = 2):
  if c > d:
    print(a)
  else:
    print(b)

# %%
myfunction(a=0, b=1, d=4)
# Out:
# 0

# %%
price = 1200

# %%
def update_price(new_price):
  price = new_price
  return price

# %%
update_price(1500)
print(price)
# Out:
# 1200
