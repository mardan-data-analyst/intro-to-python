# %%
name = "Deniz"
name
type(name)
# Out:
# str

# %%
age = 25
age
# Out:
# 25

# %%
print(name)
print(age)
# Out:
# Deniz
# 25

# %%
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Implicit type conversion

# %%
age = 25
age += 0.5
print(age, type(age))
# Out:
# 25.5 <class 'float'>

# %% [markdown]
# Explicit type conversion

# %%
string_age = "25"
print(type(string_age))
# Out:
# <class 'str'>

# %%
integer_age = int(string_age)

# %%
print(integer_age, type(integer_age))
# Out:
# 25 <class 'int'>

# %% [markdown]
# Type conversion functions

# %%
int()
float()
str()
# Out:
# ''

# %% [markdown]
# ________________________________

# %% [markdown]
# Lists

# %%
store_items = ["Apple", 1.49, 'Banana', 1, "Milk", 2.99, "Cheese", 4.49]
print(store_items, type(store_items))
# Out:
# ['Apple', 1.49, 'Banana', 1, 'Milk', 2.99, 'Cheese', 4.49] <class 'list'>

# %%
print(store_items[0])
# Out:
# Apple

# %%
print(store_items[2])
# Out:
# Banana

# %%
print(store_items[1:4])
# Out:
# [1.49, 'Banana', 1]

# %%
print(store_items[2:])
# Out:
# ['Banana', 1, 'Milk', 2.99, 'Cheese', 4.49]

# %%
print(store_items[:2])
# Out:
# ['Apple', 1.49]

# %%
store_items[2] = "Chocolate"
store_items
# Out:
# ['Apple', 1.49, 'Chocolate', 1, 'Milk', 2.99, 'Cheese', 4.49]
