# %%
pi = 3.14
if pi < 3.15:
  pi = pi + 0.1
print(pi)
# Out:
# 3.24

# %%
print(pi)
# Out:
# 3.14

# %%
# obviously this function show a greeting message according to the given name :)
def greetings(name):
  print(f"Hello, {name}")
