# %%
a = 1
b = 2
c = '3'

try:
  print('t', a+c)
except:
  c = int(c)
  print('e', a+c)
# Out:
# e 4

# %%
def foo1(num1, num2):
  try:
    return num1 + num2 + 0/1
  except:
    return "NewException"

# %%
foo1(1, 2)
# Out:
# 3.0
