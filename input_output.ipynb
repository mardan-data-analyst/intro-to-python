# %%
print("Hi, this is Python.")
# Out:
# Hi, this is Python.

# %%
name1 = 'Deniz'
print(name1)
# Out:
# Deniz

# %%
name2 = 'Selin'
print("Hello,", name2)
# Out:
# Hello, Selin

# %%
print(15)
# Out:
# 15

# %% [markdown]
# Getting input from the user

# %%
name3 = input("Name: ")
print("Hello,", name3, "!")
# Out:
# Name: Mardan
# Hello, Mardan !

# %%
number = int(input('Number: '))
print(number + 10)
# Out:
# Number: 10
# 20
