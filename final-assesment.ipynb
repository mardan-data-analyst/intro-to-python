# %% [markdown]
# # Question 1

# %%
x = 5

# %% [markdown]
# # Question 2

# %%
i = 1
while True:
  print(i)
  i += 2
  if (i == 5):
    break
# Out:
# 1
# 3

# %% [markdown]
# # Question 3

# %% [markdown]
# # Question 4

# %% [markdown]
# # Question 5

# %% [markdown]
# # Question 6

# %% [markdown]
# # Question 7

# %% [markdown]
# # Question 8
