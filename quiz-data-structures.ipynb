# %%
list_of_number = [2, 5, 6, 3, 4, 9, 2]

# %%
new_list = []
for number in list_of_number:
  inc_number = number + 1
  if inc_number < 6:
    new_list.append(number)
print(new_list)
# Out:
# [2, 3, 4, 2]

# %%
series = range(5)
print(list(series))
# Out:
# [0, 1, 2, 3, 4]

# %%
student_age_dict = {"Student1":20, "Student2":20, "Student3":30}
for student in student_age_dict.keys():
  age = student_age_dict[student]
  age += 1
print(student_age_dict)
# Out:
# {'Student1': 20, 'Student2': 20, 'Student3': 30}
