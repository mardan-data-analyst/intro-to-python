# %%
import math
import datetime
import random

# %% [markdown]
# Math operations

# %%
floor_number = (math.floor(3.45))
print(floor_number, type(floor_number))
# Out:
# 3 <class 'int'>

# %% [markdown]
# Current date and time

# %%
print(datetime.datetime.now())
# Out:
# 2022-06-25 07:31:34.762766

# %% [markdown]
# Random numbers

# %%
print(random.randint(1, 6))
# Out:
# 4
