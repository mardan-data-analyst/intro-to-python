# %%
celcius1 = 25
if celcius1 > 20:
  print("Good!")
# Out:
# Good!

# %%
celcius2 = 18
if celcius2 > 20:
  print("Good!")
else:
  print("Cold!")
# Out:
# Cold!

# %%
celcius3 = 32
if celcius3 > 30:
  print("Hot!")
if celcius3 > 20:
  print("Good!")
else:
  print("Cold!")
# Out:
# Hot!
# Good!

# %%
celcius4 = 28
if celcius4 > 30:
  print("Hot!")
elif 30 >= celcius4 > 20:
  print("Good!")
elif -273 < celcius4 <= 20:
  print("Cold!")
else:
  print("Something went wrong!")
# Out:
# Good!

# %% [markdown]
# ## Nested if statements

# %%
drivers_licence = True
age = 17

if age > 17:
  if drivers_licence:
    print("You can drive a car.")
  else:
    print("You need to go to drivers licence course.")
else:
  print("You need to get older.")
# Out:
# You need to get older.
