# %% [markdown]
# # Creating dictionary - Method 1

# %%
phone_book = {"Deniz Kaya":"+90 505 123 45 67", "Selin Demir":"+49 157 123 56 78", "Ali Can":"+1 234 235 56 78"}

# %%
print(phone_book)
# Out:
# {'Deniz Kaya': '+90 505 123 45 67', 'Selin Demir': '+49 157 123 56 78', 'Ali Can': '+1 234 235 56 78'}

# %%
print(phone_book["Deniz Kaya"])
# Out:
# +90 505 123 45 67

# %% [markdown]
# # Creating dictionary - Method 2

# %%
inventory = dict()
inventory["bananas"] = 25
inventory["apples"] = 102
inventory["oranges"] = 54
inventory["watermelons"] = 4

# %%
print(inventory)
# Out:
# {'bananas': 25, 'apples': 102, 'oranges': 54, 'watermelons': 4}

# %%
print(inventory["apples"])
# Out:
# 102

# %%
print(inventory.keys())
# Out:
# dict_keys(['bananas', 'apples', 'oranges', 'watermelons'])

# %%
print(inventory.values())
# Out:
# dict_values([25, 102, 54, 4])

# %%
print(inventory.items())
# Out:
# dict_items([('bananas', 25), ('apples', 102), ('oranges', 54), ('watermelons', 4)])

# %%
for element in inventory:
  print(element)
# Out:
# bananas
# apples
# oranges
# watermelons

# %%
for key in inventory:
  inventory[key] += 100
print(inventory)
# Out:
# {'bananas': 125, 'apples': 202, 'oranges': 154, 'watermelons': 104}

# %%
for key, value in inventory.items():
  if value > 200:
    print("Too many", key)
  else:
    print("Enough", key)
# Out:
# Enough bananas
# Too many apples
# Enough oranges
# Enough watermelons
